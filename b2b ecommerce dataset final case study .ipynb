# %% [markdown]
# # scenario 1

# %% [markdown]
# #  Task 1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as  plt
# %matplotlib inline

# %%
#lets import data
df=pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\dataset.csv",encoding = 'ISO-8859-1')
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.describe(include = 'all')
# Out:
#        InvoiceNo StockCode                         Description       Quantity  \
# count     541909    541909                              540455  541909.000000
# unique     25900      4070                                4223            NaN
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        1114      2313                                2369            NaN
# mean         NaN       NaN                                 NaN       9.552250
# std          NaN       NaN                                 NaN     218.081158
# min          NaN       NaN                                 NaN  -80995.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   80995.000000
#
#              InvoiceDate      UnitPrice     CustomerID         Country
# count             541909  541909.000000  406829.000000          541909
# unique             23260            NaN            NaN              38
# top     10/31/2011 14:41            NaN            NaN  United Kingdom
# freq                1114            NaN            NaN          495478
# mean                 NaN       4.611114   15287.690570             NaN
# std                  NaN      96.759853    1713.600303             NaN
# min                  NaN  -11062.060000   12346.000000             NaN
# 25%                  NaN       1.250000   13953.000000             NaN
# 50%                  NaN       2.080000   15152.000000             NaN
# 75%                  NaN       4.130000   16791.000000             NaN
# max                  NaN   38970.000000   18287.000000             NaN

# %% [markdown]
# 1.Quantity having many negative values and outlier
#
# 2.unitprice having many negative values and outlier
#
# 3.in dataframe 5268 duplicate values
#
# 4.description and customer id having missing value

# %% [markdown]
# #  Task 2

# %%
# 1. Convert the records under the column "Description" into string title format
df['Description'] = df['Description'].str.title()

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   White Hanging Heart T-Light Holder         6
# 1    536365     71053                  White Metal Lantern         6
# 2    536365    84406B       Cream Cupid Hearts Coat Hanger         8
# 3    536365    84029G  Knitted Union Flag Hot Water Bottle         6
# 4    536365    84029E       Red Woolly Hottie White Heart.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# 2.Change the format of "InvoiceDate" as datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   White Hanging Heart T-Light Holder         6
# 1    536365     71053                  White Metal Lantern         6
# 2    536365    84406B       Cream Cupid Hearts Coat Hanger         8
# 3    536365    84029G  Knitted Union Flag Hot Water Bottle         6
# 4    536365    84029E       Red Woolly Hottie White Heart.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# 3. Create four columns on the basis of "InvoiceDate" on following logic;

df["hour"]=df["InvoiceDate"].dt.hour
df["day"]=df["InvoiceDate"].dt.day_name()
df["month"]=df["InvoiceDate"].dt.month_name()
df["MonthYear"]=df["InvoiceDate"].dt.strftime("%b-%Y")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   White Hanging Heart T-Light Holder         6
# 1    536365     71053                  White Metal Lantern         6
# 2    536365    84406B       Cream Cupid Hearts Coat Hanger         8
# 3    536365    84029G  Knitted Union Flag Hot Water Bottle         6
# 4    536365    84029E       Red Woolly Hottie White Heart.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  hour        day  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     8  Wednesday
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  Wednesday
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     8  Wednesday
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  Wednesday
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  Wednesday
#
#       month MonthYear
# 0  December  Dec-2010
# 1  December  Dec-2010
# 2  December  Dec-2010
# 3  December  Dec-2010
# 4  December  Dec-2010

# %% [markdown]
# # Scenario 2

# %% [markdown]
# ### Task 1

# %%
# 1. Create a new dataframe that includes the records if any na is found in the dataset. Save it as "missing_dataset"
missing_data=df[df.isna().any(axis=1)]
missing_data.head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                              NaN        56
# 1443    536544     21773  Decorative Rose Bathroom Bottle         1
# 1444    536544     21774  Decorative Cats Bathroom Bottle         2
# 1445    536544     21786               Polkadot Rain Hat          4
# 1446    536544     21787            Rain Poncho Retrospot         2
#
#              InvoiceDate  UnitPrice  CustomerID         Country  hour  \
# 622  2010-12-01 11:52:00       0.00         NaN  United Kingdom    11
# 1443 2010-12-01 14:32:00       2.51         NaN  United Kingdom    14
# 1444 2010-12-01 14:32:00       2.51         NaN  United Kingdom    14
# 1445 2010-12-01 14:32:00       0.85         NaN  United Kingdom    14
# 1446 2010-12-01 14:32:00       1.66         NaN  United Kingdom    14
#
#             day     month MonthYear
# 622   Wednesday  December  Dec-2010
# 1443  Wednesday  December  Dec-2010
# 1444  Wednesday  December  Dec-2010
# 1445  Wednesday  December  Dec-2010
# 1446  Wednesday  December  Dec-2010

# %%
# 2. Insert a new column to "missing_dataset" with InvoiceDate datetime logic that is shall display "DayName-MonthName-Year" and provide its header as "DayMonthYear". 
#Eg: Values shall be "Wed-Dec-10", "Fri-Dec-10", "Thu-Jan-11" ...

missing_data['DayMonthYear'] = pd.to_datetime(missing_data['InvoiceDate']).dt.strftime('%a-%b-%y')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15132\139929071.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_data['DayMonthYear'] = pd.to_datetime(missing_data['InvoiceDate']).dt.strftime('%a-%b-%y')

# %%
missing_data.head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                              NaN        56
# 1443    536544     21773  Decorative Rose Bathroom Bottle         1
# 1444    536544     21774  Decorative Cats Bathroom Bottle         2
# 1445    536544     21786               Polkadot Rain Hat          4
# 1446    536544     21787            Rain Poncho Retrospot         2
#
#              InvoiceDate  UnitPrice  CustomerID         Country  hour  \
# 622  2010-12-01 11:52:00       0.00         NaN  United Kingdom    11
# 1443 2010-12-01 14:32:00       2.51         NaN  United Kingdom    14
# 1444 2010-12-01 14:32:00       2.51         NaN  United Kingdom    14
# 1445 2010-12-01 14:32:00       0.85         NaN  United Kingdom    14
# 1446 2010-12-01 14:32:00       1.66         NaN  United Kingdom    14
#
#             day     month MonthYear DayMonthYear
# 622   Wednesday  December  Dec-2010   Wed-Dec-10
# 1443  Wednesday  December  Dec-2010   Wed-Dec-10
# 1444  Wednesday  December  Dec-2010   Wed-Dec-10
# 1445  Wednesday  December  Dec-2010   Wed-Dec-10
# 1446  Wednesday  December  Dec-2010   Wed-Dec-10

# %%
missing_data.shape
# Out:
# (135080, 13)

# %%
# 3. Create a group "missing_group_1" that shows total records against MonthYear. Make a visualizing chart for it.

missing_group_1=missing_data.groupby("MonthYear").size().reset_index(name="count")

missing_group_1.sort_values(by="count",ascending=False)
# Out:
#    MonthYear  count
# 10  Nov-2011  19113
# 2   Dec-2010  15631
# 5   Jan-2011  13235
# 6   Jul-2011  12016
# 11  Oct-2011  10047
# 12  Sep-2011   9404
# 7   Jun-2011   9038
# 8   Mar-2011   8926
# 9   May-2011   8122
# 3   Dec-2011   7864
# 1   Aug-2011   7622
# 4   Feb-2011   7344
# 0   Apr-2011   6718

# %%
# create a bar chart to visualize the group "missing_group_1"
fig = plt.figure(figsize=(20, 5))
plt.bar(missing_group_1['MonthYear'], missing_group_1['count'])
plt.xlabel('Month-Year')
plt.ylabel('Total Records')
plt.title('Missing Group 1')
plt.show()

# %% [markdown]
#  it can clearly shows that november has maximum missing values according to above graph.

# %%
# 4. Create a group "missing_group_2" that shows total records against DayMonthYear. Make a visualizing chart for it.

missing_group_2 = missing_data.groupby('DayMonthYear').size().reset_index(name="count")

missing_group_2
# Out:
#    DayMonthYear  count
# 0    Fri-Apr-11   1218
# 1    Fri-Aug-11    675
# 2    Fri-Dec-10   4778
# 3    Fri-Dec-11   1870
# 4    Fri-Feb-11   1218
# ..          ...    ...
# 71   Wed-Mar-11    831
# 72   Wed-May-11    704
# 73   Wed-Nov-11   4321
# 74   Wed-Oct-11   1448
# 75   Wed-Sep-11   3365
#
# [76 rows x 2 columns]

# %%
plt.figure(figsize=(50,20))
sns.set_theme(font_scale=3.5)
sns.barplot(missing_group_2['DayMonthYear'], missing_group_2['count'])
plt.xlabel('Day-Month-Year')
plt.ylabel('Total Records')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Tue-oct-11 have maximimu null values

# %% [markdown]
# ### Task 2

# %%
# 1.Create a dataframe "cancelled_orders" that filter the records having Invoice Number starting with "C". Here "C" represents the cancelled orders.

cancelled_orders = df[df['InvoiceNo'].str.startswith('C')]

# %%
cancelled_orders.head(5)
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   Set Of 3 Coloured  Flying Ducks        -1
# 235   C536391     22556    Plasters In Tin Circus Parade        -12
# 236   C536391     21984  Pack Of 12 Pink Paisley Tissues        -24
# 237   C536391     21983  Pack Of 12 Blue Paisley Tissues        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country  hour  \
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom     9
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom     9
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom    10
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom    10
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom    10
#
#            day     month MonthYear
# 141  Wednesday  December  Dec-2010
# 154  Wednesday  December  Dec-2010
# 235  Wednesday  December  Dec-2010
# 236  Wednesday  December  Dec-2010
# 237  Wednesday  December  Dec-2010

# %%
# 2
cancelled_orders_discounts = cancelled_orders[cancelled_orders["StockCode"] == "D"]
cancelled_orders_discounts.head()
# Out:
#       InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 141     C536379         D    Discount        -1 2010-12-01 09:41:00
# 9038    C537164         D    Discount        -1 2010-12-05 13:21:00
# 14498   C537597         D    Discount        -1 2010-12-07 12:34:00
# 19392   C537857         D    Discount        -1 2010-12-08 16:00:00
# 31134   C538897         D    Discount        -1 2010-12-15 09:14:00
#
#        UnitPrice  CustomerID         Country  hour        day     month  \
# 141        27.50     14527.0  United Kingdom     9  Wednesday  December
# 9038       29.29     14527.0  United Kingdom    13     Sunday  December
# 14498     281.00     15498.0  United Kingdom    12    Tuesday  December
# 19392     267.12     17340.0  United Kingdom    16  Wednesday  December
# 31134       5.76     16422.0  United Kingdom     9  Wednesday  December
#
#       MonthYear
# 141    Dec-2010
# 9038   Dec-2010
# 14498  Dec-2010
# 19392  Dec-2010
# 31134  Dec-2010

# %%
#how many cancell orders
cancelled_orders.shape
# Out:
# (9288, 12)

# %%
cancelled_orders.describe(include = 'all')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15132\2015608520.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   cancelled_orders.describe(include = 'all')
#        InvoiceNo StockCode Description      Quantity          InvoiceDate  \
# count       9288      9288        9288   9288.000000                 9288
# unique      3836      1947        1972           NaN                 3766
# top      C570867         M      Manual           NaN  2011-10-12 16:17:00
# freq         101       244         244           NaN                  101
# first        NaN       NaN         NaN           NaN  2010-12-01 09:41:00
# last         NaN       NaN         NaN           NaN  2011-12-09 11:58:00
# mean         NaN       NaN         NaN    -29.885228                  NaN
# std          NaN       NaN         NaN   1145.786965                  NaN
# min          NaN       NaN         NaN -80995.000000                  NaN
# 25%          NaN       NaN         NaN     -6.000000                  NaN
# 50%          NaN       NaN         NaN     -2.000000                  NaN
# 75%          NaN       NaN         NaN     -1.000000                  NaN
# max          NaN       NaN         NaN     -1.000000                  NaN
#
#            UnitPrice    CustomerID         Country         hour       day  \
# count    9288.000000   8905.000000            9288  9288.000000      9288
# unique           NaN           NaN              30          NaN         6
# top              NaN           NaN  United Kingdom          NaN  Thursday
# freq             NaN           NaN            7856          NaN      2355
# first            NaN           NaN             NaN          NaN       NaN
# last             NaN           NaN             NaN          NaN       NaN
# mean       48.393661  14991.667266             NaN    13.152024       NaN
# std       666.600430   1706.772357             NaN     2.700102       NaN
# min         0.010000  12346.000000             NaN     6.000000       NaN
# 25%         1.450000  13510.000000             NaN    11.000000       NaN
# 50%         2.950000  14895.000000             NaN    13.000000       NaN
# 75%         5.950000  16393.000000             NaN    15.000000       NaN
# max     38970.000000  18282.000000             NaN    20.000000       NaN
#
#           month MonthYear
# count      9288      9288
# unique       12        13
# top     October  Oct-2011
# freq       1200      1200
# first       NaN       NaN
# last        NaN       NaN
# mean        NaN       NaN
# std         NaN       NaN
# min         NaN       NaN
# 25%         NaN       NaN
# 50%         NaN       NaN
# 75%         NaN       NaN
# max         NaN       NaN

# %%
cancelled_orders.Quantity.value_counts()
# Out:
# -1        4105
# -2        1337
# -3         581
# -12        546
# -6         482
#           ...
# -701         1
# -252         1
# -334         1
# -318         1
# -80995       1
# Name: Quantity, Length: 135, dtype: int64

# %% [markdown]
# all cancell orders having quantity in negative

# %%
cancelled_orders.groupby('MonthYear')['InvoiceNo'].count().sort_values(ascending=False).head()
# Out:
# MonthYear
# Oct-2011    1200
# Nov-2011    1076
# Sep-2011     805
# Dec-2010     728
# Jun-2011     711
# Name: InvoiceNo, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.xticks(fontsize=10, rotation = 'vertical')
sns.set_theme(font_scale=2.5)
sns.countplot(x=cancelled_orders['MonthYear'], order = cancelled_orders.MonthYear.value_counts().
               sort_values(ascending=False).index)
plt.title('cancelled orders by monthyear')
# Out:
# Text(0.5, 1.0, 'cancelled orders by monthyear')

# %% [markdown]
# oct-2011 has maximum cancelled orders.

# %%
# which country have maximum cancell orders
cancelled_orders.groupby('Country').size().sort_values(ascending=False).head(10)
# Out:
# Country
# United Kingdom    7856
# Germany            453
# EIRE               302
# France             149
# USA                112
# Australia           74
# Spain               48
# Italy               45
# Belgium             38
# Japan               37
# dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.xticks(fontsize=10, rotation = 'vertical')
sns.countplot(x=cancelled_orders['Country'], order = cancelled_orders.Country.value_counts().
               sort_values(ascending=False).index)
plt.title('cancelled orders by country')
# Out:
# Text(0.5, 1.0, 'cancelled orders by country')

# %% [markdown]
# united kingdom have maximum cancelled orders

# %%
cancelled_orders.groupby("CustomerID")['InvoiceNo'].count().sort_values(ascending=False).head()
# Out:
# CustomerID
# 14911.0    226
# 17841.0    136
# 17511.0    113
# 15311.0    112
# 12607.0    101
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# #.United Kingdom has maximum cancell orders 7856,
# #.in october_2011 we have maxium cancell ordes 1200,
# #.customerid  14911 have amake maximum cancell_orders 226.

# %%
cancelled_orders_discounts.head(5)
# Out:
#       InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 141     C536379         D    Discount        -1 2010-12-01 09:41:00
# 9038    C537164         D    Discount        -1 2010-12-05 13:21:00
# 14498   C537597         D    Discount        -1 2010-12-07 12:34:00
# 19392   C537857         D    Discount        -1 2010-12-08 16:00:00
# 31134   C538897         D    Discount        -1 2010-12-15 09:14:00
#
#        UnitPrice  CustomerID         Country  hour        day     month  \
# 141        27.50     14527.0  United Kingdom     9  Wednesday  December
# 9038       29.29     14527.0  United Kingdom    13     Sunday  December
# 14498     281.00     15498.0  United Kingdom    12    Tuesday  December
# 19392     267.12     17340.0  United Kingdom    16  Wednesday  December
# 31134       5.76     16422.0  United Kingdom     9  Wednesday  December
#
#       MonthYear
# 141    Dec-2010
# 9038   Dec-2010
# 14498  Dec-2010
# 19392  Dec-2010
# 31134  Dec-2010

# %%
#how many cancelled orders having discount
cancelled_orders_discounts['InvoiceNo'].count()
# Out:
# 77

# %%
# how much discount against cancelled orders
cancelled_orders_discounts['UnitPrice'].sum()
# Out:
# 5581.3099999999995

# %%
cancelled_orders_discounts.describe()
# Out:
#          Quantity    UnitPrice    CustomerID       hour
# count   77.000000    77.000000     77.000000  77.000000
# mean   -15.506494    72.484545  14926.831169  12.597403
# std     86.557043   219.271071   1188.672008   2.535328
# min   -720.000000     0.010000  12830.000000   6.000000
# 25%     -1.000000    13.880000  14527.000000  12.000000
# 50%     -1.000000    22.970000  14527.000000  12.000000
# 75%     -1.000000    57.600000  15796.000000  14.000000
# max     -1.000000  1867.860000  18167.000000  19.000000

# %%
#created a bar chart to visualize the trend of discounts in cancelled orders
cancelled_orders_discounts.groupby("MonthYear")['UnitPrice'].sum().plot(kind='bar')
plt.title('Monthly Discount Amounts for Cancelled Orders')
plt.xlabel('Month')
plt.ylabel('Total Discount Amount')
plt.show()

# %% [markdown]
# Apr having maximim dicount against cancell orders

# %%
plt.figure(figsize = (15,5))

sns.barplot(x='Country',y='UnitPrice',data=cancelled_orders_discounts);

plt.show()

# %% [markdown]
# EIRE has got the maximum discount against the cancelled orders

# %% [markdown]
# ### Task 3

# %%
#task 3
df.shape
# Out:
# (541909, 12)

# %%
#removung missing value
df=df.dropna()
df.shape
# Out:
# (406829, 12)

# %%
#removing negative Quantity
df=df[df["Quantity"]>=0]
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID           hour
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean       13.021823       3.116174   15294.315171      12.728247
# std       180.420210      22.096788    1713.169877       2.273535
# min         1.000000       0.000000   12346.000000       6.000000
# 25%         2.000000       1.250000   13969.000000      11.000000
# 50%         6.000000       1.950000   15159.000000      13.000000
# 75%        12.000000       3.750000   16795.000000      14.000000
# max     80995.000000    8142.750000   18287.000000      20.000000

# %%
# 3. create a field "AmountSpent" that is multplication of Quantity and Unit Price.
df['AmountSpent'] = df['Quantity'] * df['UnitPrice']

# %%
# 4. Convert field "CustomerID" as int64 datatype.
df['CustomerID'] = df['CustomerID'].astype('int64')

# %%
df['InvoiceNo']=df['InvoiceNo'].astype(int)

# %% [markdown]
# # scenario 3

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# hour           0
# day            0
# month          0
# MonthYear      0
# AmountSpent    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397924 entries, 0 to 541908
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  int32
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  datetime64[ns]
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  int64
#  7   Country      397924 non-null  object
#  8   hour         397924 non-null  int64
#  9   day          397924 non-null  object
#  10  month        397924 non-null  object
#  11  MonthYear    397924 non-null  object
#  12  AmountSpent  397924 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(3), object(6)
# memory usage: 41.0+ MB

# %%
df.sample(5)
# Out:
#         InvoiceNo StockCode                        Description  Quantity  \
# 212985     555515     22200           Frying Pan Pink Polkadot         2
# 320894     565117     23148  Miniature Antique Rose Hook Ivory        24
# 298566     563023     48187                Doormat New England         2
# 133413     547786     20727            Lunch Bag  Black Skull.         3
# 244574     558536     22222          Cake Plate Lovebird White        72
#
#                InvoiceDate  UnitPrice  CustomerID         Country  hour  \
# 212985 2011-06-05 10:47:00       4.25       17690  United Kingdom    10
# 320894 2011-09-01 11:33:00       0.83       13089  United Kingdom    11
# 298566 2011-08-11 13:39:00       7.95       14639  United Kingdom    13
# 133413 2011-03-25 11:44:00       1.65       14587  United Kingdom    11
# 244574 2011-06-30 12:06:00       4.25       12424       Australia    12
#
#              day      month MonthYear  AmountSpent
# 212985    Sunday       June  Jun-2011         8.50
# 320894  Thursday  September  Sep-2011        19.92
# 298566  Thursday     August  Aug-2011        15.90
# 133413    Friday      March  Mar-2011         4.95
# 244574  Thursday       June  Jun-2011       306.00

# %%
df.duplicated().sum()
# Out:
# 5192

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (392732, 13)

# %% [markdown]
# #  removing outliers

# %%
q1=2
q3=12
iqr=q3-q1
lower_limit=q1 - 1.5 * iqr
upper_limit=q3 + 1.5 * iqr
lower_limit
upper_limit
df2=df[(df.Quantity<upper_limit) & (df.Quantity>lower_limit)]

# %%
q1=1.250000
q3=3.750000
iqr=q3-q1
lower_limit=q1 - 1.5 * iqr
upper_limit=q3 + 1.5 * iqr
lower_limit
upper_limit
df3=df2[(df.UnitPrice<upper_limit) & (df2.UnitPrice>lower_limit)]
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15132\3210833271.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3=df2[(df.UnitPrice<upper_limit) & (df2.UnitPrice>lower_limit)]

# %%
q1=3.750000
q3=17.400000
iqr=q3-q1
lower_limit=q1 - 1.5 * iqr
upper_limit=q3 + 1.5 * iqr
lower_limit
upper_limit
df4=df3[(df2.AmountSpent<upper_limit) & (df3.AmountSpent>lower_limit)]
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15132\2918181742.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df4=df3[(df2.AmountSpent<upper_limit) & (df3.AmountSpent>lower_limit)]

# %%
df4.shape
# Out:
# (319353, 13)

# %% [markdown]
# # EDA (Exploratioary Data Analysis)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319353 entries, 0 to 541908
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    319353 non-null  int32
#  1   StockCode    319353 non-null  object
#  2   Description  319353 non-null  object
#  3   Quantity     319353 non-null  int64
#  4   InvoiceDate  319353 non-null  datetime64[ns]
#  5   UnitPrice    319353 non-null  float64
#  6   CustomerID   319353 non-null  int64
#  7   Country      319353 non-null  object
#  8   hour         319353 non-null  int64
#  9   day          319353 non-null  object
#  10  month        319353 non-null  object
#  11  MonthYear    319353 non-null  object
#  12  AmountSpent  319353 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(3), object(6)
# memory usage: 32.9+ MB

# %%
df4.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   White Hanging Heart T-Light Holder         6
# 1     536365     71053                  White Metal Lantern         6
# 2     536365    84406B       Cream Cupid Hearts Coat Hanger         8
# 3     536365    84029G  Knitted Union Flag Hot Water Bottle         6
# 4     536365    84029E       Red Woolly Hottie White Heart.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  hour        day  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom     8  Wednesday
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom     8  Wednesday
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom     8  Wednesday
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom     8  Wednesday
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom     8  Wednesday
#
#       month MonthYear  AmountSpent
# 0  December  Dec-2010        15.30
# 1  December  Dec-2010        20.34
# 2  December  Dec-2010        22.00
# 3  December  Dec-2010        20.34
# 4  December  Dec-2010        20.34

# %% [markdown]
# # Univariate  analysis

# %%
df4.describe(include = 'all')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15132\3817360777.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df4.describe(include = 'all')
#             InvoiceNo StockCode                         Description  \
# count   319353.000000    319353                              319353
# unique            NaN      3310                                3489
# top               NaN    85123A  White Hanging Heart T-Light Holder
# freq              NaN      1587                                1581
# first             NaN       NaN                                 NaN
# last              NaN       NaN                                 NaN
# mean    560809.378331       NaN                                 NaN
# std      13119.045667       NaN                                 NaN
# min     536365.000000       NaN                                 NaN
# 25%     549300.000000       NaN                                 NaN
# 50%     562162.000000       NaN                                 NaN
# 75%     572291.000000       NaN                                 NaN
# max     581587.000000       NaN                                 NaN
#
#              Quantity          InvoiceDate      UnitPrice     CustomerID  \
# count   319353.000000               319353  319353.000000  319353.000000
# unique            NaN                15268            NaN            NaN
# top               NaN  2011-11-14 15:27:00            NaN            NaN
# freq              NaN                  447            NaN            NaN
# first             NaN  2010-12-01 08:26:00            NaN            NaN
# last              NaN  2011-12-09 12:50:00            NaN            NaN
# mean         7.151265                  NaN       2.116001   15331.771895
# std          6.495136                  NaN       1.485882    1709.926500
# min          1.000000                  NaN       0.000000   12347.000000
# 25%          2.000000                  NaN       0.950000   14002.000000
# 50%          5.000000                  NaN       1.650000   15258.000000
# 75%         12.000000                  NaN       2.950000   16837.000000
# max         26.000000                  NaN       7.460000   18287.000000
#
#                Country           hour       day     month MonthYear  \
# count           319353  319353.000000    319353    319353    319353
# unique              37            NaN         6        12        13
# top     United Kingdom            NaN  Thursday  November  Nov-2011
# freq            288642            NaN     63038     53054     53054
# first              NaN            NaN       NaN       NaN       NaN
# last               NaN            NaN       NaN       NaN       NaN
# mean               NaN      12.787570       NaN       NaN       NaN
# std                NaN       2.247893       NaN       NaN       NaN
# min                NaN       6.000000       NaN       NaN       NaN
# 25%                NaN      11.000000       NaN       NaN       NaN
# 50%                NaN      13.000000       NaN       NaN       NaN
# 75%                NaN      14.000000       NaN       NaN       NaN
# max                NaN      20.000000       NaN       NaN       NaN
#
#           AmountSpent
# count   319353.000000
# unique            NaN
# top               NaN
# freq              NaN
# first             NaN
# last              NaN
# mean        10.958588
# std          8.241622
# min          0.000000
# 25%          3.750000
# 50%          9.900000
# 75%         16.500000
# max         37.800000

# %%
df4.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319353 entries, 0 to 541908
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    319353 non-null  int32
#  1   StockCode    319353 non-null  object
#  2   Description  319353 non-null  object
#  3   Quantity     319353 non-null  int64
#  4   InvoiceDate  319353 non-null  datetime64[ns]
#  5   UnitPrice    319353 non-null  float64
#  6   CustomerID   319353 non-null  int64
#  7   Country      319353 non-null  object
#  8   hour         319353 non-null  int64
#  9   day          319353 non-null  object
#  10  month        319353 non-null  object
#  11  MonthYear    319353 non-null  object
#  12  AmountSpent  319353 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(3), object(6)
# memory usage: 32.9+ MB

# %%
# Create a histogram of the UnitPrice column
plt.hist(df4['UnitPrice'], bins=50)
plt.title('UnitPrice Distribution')
plt.xlabel('UnitPrice')
plt.ylabel('Frequency')
plt.show()

# %%
# how manny transacction are occured
df4['InvoiceNo'].nunique()
# Out:
# 16252

# %% [markdown]
# there are total 18536 transaction are occured in this dataset

# %%
#how many unique product in dataset
df4["Description"].nunique()
# Out:
# 3489

# %% [markdown]
# there are total 3877 types of product are in dataset

# %%
#whuch product has high sell the most
df4['Description'].value_counts().head()
# Out:
# White Hanging Heart T-Light Holder    1581
# Lunch Bag Red Retrospot               1190
# Jumbo Bag Red Retrospot               1144
# Set Of 3 Cake Tins Pantry Design      1039
# Lunch Bag  Black Skull.               1020
# Name: Description, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.xticks(fontsize=10, rotation = 'vertical')
sns.set_theme(font_scale=1.5)
sns.countplot(x=df4['Country'], order = df4.Country.value_counts().
               sort_values(ascending=False).index)
plt.title('country wise sales')
# Out:
# Text(0.5, 1.0, 'country wise sales')

# %% [markdown]
# united kingdom has highest order country according to this graph.

# %%
#which date have maximum orders
df4['InvoiceDate'].nunique()
# Out:
# 15268

# %%
# in whic date has maximum orders
df4['InvoiceDate'].value_counts().head()
# Out:
# 2011-11-14 15:27:00    447
# 2011-11-28 15:54:00    438
# 2011-12-05 17:17:00    421
# 2011-10-31 14:09:00    380
# 2011-09-21 14:40:00    364
# Name: InvoiceDate, dtype: int64

# %%
# total unit orders in 1 year
df4['Quantity'].sum()
# Out:
# 2283778

# %%
df4["Quantity"].value_counts().head(10)
# Out:
# 1     57629
# 12    56393
# 2     43002
# 6     36133
# 4     28883
# 3     25290
# 10    19934
# 24    18813
# 8     10234
# 5      7826
# Name: Quantity, dtype: int64

# %%
#how many customer that orders product
df4["CustomerID"].nunique()
# Out:
# 4146

# %%
#which customer having max sales
df4["CustomerID"].value_counts().head().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# how much countery are buying product
df4['Country'].nunique()
# Out:
# 37

# %%
#which country have maximum orders
df['Country'].value_counts().head(10)
# Out:
# United Kingdom    349227
# Germany             9027
# France              8327
# EIRE                7228
# Spain               2480
# Netherlands         2363
# Belgium             2031
# Switzerland         1842
# Portugal            1453
# Australia           1184
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.subplot(2, 2, 1)
df4['MonthYear'].value_counts().plot(kind='bar')
plt.title('Number of Transactions per Year')
plt.xlabel('Year')
plt.ylabel('Number of Transactions')
# Out:
# Text(0, 0.5, 'Number of Transactions')

# %%
plt.figure(figsize=(15,8))
plt.subplot(2, 2, 3)
df4['day'].value_counts().plot(kind='bar')
plt.title('Number of Transactions per Day')
plt.xlabel('day')
plt.ylabel('Number of Transactions')
# Out:
# Text(0, 0.5, 'Number of Transactions')

# %%
plt.figure(figsize=(15,8))
plt.subplot(2, 2, 2)
df4['month'].value_counts().plot(kind='bar')
plt.title('Number of Transactions per Month')
plt.xlabel('month')
plt.ylabel('Number of Transactions')
# Out:
# Text(0, 0.5, 'Number of Transactions')

# %%
plt.figure(figsize=(15,8))
plt.subplot(2, 2, 1)
df4['UnitPrice'].plot(kind='hist', bins=50)
plt.title('Distribution of UnitPrice')
plt.xlabel('UnitPrice')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(15,8))
plt.subplot(2, 2, 2)
df4['Quantity'].plot(kind='hist', bins=50)
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#total revenue
df4["AmountSpent"].sum()
# Out:
# 3499657.7939999998

# %% [markdown]
# # bivariate analysis

# %%
plt.figure(figsize = (20,5))

sns.barplot(x='MonthYear',y='AmountSpent',data=df4);

plt.show()

# %% [markdown]
# may-2011 and sep-2011 has highest revenue.

# %%
top_revenue_generated_country = df4.groupby('Country')['AmountSpent'].sum().sort_values(ascending = False)
top_revenue_generated_country
# Out:
# Country
# United Kingdom          3010986.624
# Germany                  112813.430
# France                   101806.970
# EIRE                      83264.390
# Spain                     27040.550
# Belgium                   26021.740
# Switzerland               22467.500
# Portugal                  17422.810
# Norway                    11673.070
# Italy                     10150.660
# Channel Islands            9012.470
# Finland                    8015.350
# Australia                  6772.000
# Cyprus                     6279.480
# Netherlands                6201.280
# Austria                    5256.670
# Denmark                    4419.180
# Poland                     4258.000
# Sweden                     4031.320
# Iceland                    2783.370
# Israel                     2616.730
# USA                        2548.110
# Unspecified                1975.780
# Canada                     1896.540
# Singapore                  1881.740
# Greece                     1629.180
# Malta                      1441.670
# United Arab Emirates       1095.340
# European Community          800.550
# RSA                         734.360
# Japan                       715.900
# Lebanon                     500.330
# Brazil                      317.340
# Czech Republic              239.640
# Lithuania                   233.100
# Bahrain                     208.700
# Saudi Arabia                145.920
# Name: AmountSpent, dtype: float64

# %%
plt.figure(figsize = (20,10))
sns.set_theme(font_scale=1.0)

sns.barplot(x='Country',y='AmountSpent',data=df4,estimator=sum);
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# united kingdom is the top revenue generated company of this dataset.

# %%
plt.figure(figsize=(15,8))
plt.scatter(df4['Quantity'], df4['AmountSpent'])
plt.title('Quantity vs AmountSpent')
plt.xlabel('Quantity')
plt.ylabel('AmountSpent')
plt.show()

# %%
#Top 10 product base on amountspent
df.groupby('Description')['AmountSpent'].sum().sort_values(ascending = False)
# Out:
# Description
# Paper Craft , Little Birdie           168469.600
# Regency Cakestand 3 Tier              142264.750
# White Hanging Heart T-Light Holder    100392.100
# Jumbo Bag Red Retrospot                85040.540
# Medium Ceramic Top Storage Jar         81416.730
#                                          ...
# Pink Crystal Guitar Phone Charm            0.850
# Vintage Blue Tinsel Reel                   0.840
# Set 12 Colouring Pencils Doiley            0.650
# Hen House W Chick In Nest                  0.420
# Pads To Match All Cushions                 0.003
# Name: AmountSpent, Length: 3877, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x=df4['Country'], y=df4['AmountSpent'])
plt.title('AmountSpent by Country')
plt.xlabel('Country')
plt.ylabel('AmountSpent')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #  multivariate analysis

# %%
# Group the data by Country and CustomerID and calculate the total revenue for each customer in each country
revenue_by_customer = df4.groupby(["Country", "CustomerID"])["AmountSpent"].sum().reset_index()

# Plot the total revenue for each customer in the top 10 countries with the most customers
top_countries = df4["Country"].value_counts().head(10).index
sns.boxplot(x="Country", y="AmountSpent", data=revenue_by_customer[revenue_by_customer["Country"].isin(top_countries)])
plt.xticks(rotation=90)
plt.show()

# %%
top_country_per_monthyear = df4[['Country','MonthYear','AmountSpent']].sort_values(by = 'AmountSpent',ascending = False).head(10)
top_country_per_monthyear
# Out:
#                Country MonthYear  AmountSpent
# 113833  United Kingdom  Mar-2011         37.8
# 524610  United Kingdom  Dec-2011         37.8
# 392549  United Kingdom  Oct-2011         37.8
# 30565   United Kingdom  Dec-2010         37.8
# 34477          Germany  Dec-2010         37.8
# 469736         Germany  Nov-2011         37.8
# 139787  United Kingdom  Mar-2011         37.8
# 314864  United Kingdom  Aug-2011         37.8
# 288323  United Kingdom  Aug-2011         37.8
# 526189  United Kingdom  Dec-2011         37.8

# %% [markdown]
# these are the top 10 countries from which ecommerce generated most revenue.

# %%
# Group the data by Country, CustomerID and month of transaction and calculate the total revenue, quantity and number of transactions for each customer
df4["TransactionMonth"] = df4["MonthYear"]
customer_summary = df4.groupby(["Country", "CustomerID", "TransactionMonth"]).agg({
    "AmountSpent": "sum",
    "Quantity": "sum",
    "InvoiceNo": "nunique"
}).reset_index()

# Plot the total revenue, quantity and number of transactions for each customer in the top 10 countries with the most customers
sns.pairplot(data=customer_summary[customer_summary["Country"].isin(top_countries)], 
             vars=["AmountSpent", "Quantity", "InvoiceNo"], 
             hue="Country",
             diag_kind="hist",
             diag_kws={"bins": 20},
             plot_kws={"alpha": 0.7},
             height=3)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15132\2733259768.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4["TransactionMonth"] = df4["MonthYear"]

# %% [markdown]
# #  correlation of variable

# %%
corr = df4[["AmountSpent", "Quantity", "UnitPrice"]].corr()
corr
# Out:
#              AmountSpent  Quantity  UnitPrice
# AmountSpent     1.000000  0.506417   0.284838
# Quantity        0.506417  1.000000  -0.432443
# UnitPrice       0.284838 -0.432443   1.000000
